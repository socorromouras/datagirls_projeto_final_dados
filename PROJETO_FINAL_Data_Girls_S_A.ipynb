# %% [markdown]
# # 📊 - PROJETO FINAL - **EMPRESA: Data Girls S.A**

# %% [markdown]
# **OBJETIVO:**
# * Explorar indicadores de **rotatividade** (attrition) de funcionários e construir um dashboard interativo que ajudem a empresa fictícia **Data Girls S.A** a tomar decisões estratégicas de RH;

# %% [markdown]
# ## **1. Leitura e Exploração Inicial:**

# %% [markdown]
# **Importando biblioteca**

# %%
import pandas as pd

# %% [markdown]
# **Leitura dos dados**

# %%
df = pd.read_csv('/content/drive/MyDrive/(RE) START - Data Girls/PROJETO FINAL/RH-DATASET.csv')

# %%
# Tabela Completa:

df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## **2. Limpeza e Preparação dos Dados:**

# %%
# Informações Gerais:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Identificando os NULOS:

print(df.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#  Identificando DUPLICADOS

duplicatas = df.duplicated()
print(duplicatas)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# Importando as Bibliotecas:

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Histogramas**

# %%
sns.histplot(data=df, x="Age",kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x="DailyRate",kde=True)
# Out:
# <Axes: xlabel='DailyRate', ylabel='Count'>

# %%
# ATENÇÃO: Distância de Casa

sns.histplot(data=df, x="DistanceFromHome",kde=True)
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='Count'>

# %%
sns.histplot(data=df, x="HourlyRate",kde=True)
# Out:
# <Axes: xlabel='HourlyRate', ylabel='Count'>

# %%
#ATENÇÃO: Salário Mensal

sns.histplot(data=df, x="MonthlyIncome",kde=True)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.histplot(data=df, x="MonthlyRate",kde=True)
# Out:
# <Axes: xlabel='MonthlyRate', ylabel='Count'>

# %%
sns.histplot(data=df, x="NumCompaniesWorked",kde=True)
# Out:
# <Axes: xlabel='NumCompaniesWorked', ylabel='Count'>

# %%
# ATENÇÃO: Aumento Salarial Percentual

sns.histplot(data=df, x="PercentSalaryHike",kde=True)
# Out:
# <Axes: xlabel='PercentSalaryHike', ylabel='Count'>

# %%
sns.histplot(data=df, x="TotalWorkingYears",kde=True)
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='Count'>

# %%
sns.histplot(data=df, x="TrainingTimesLastYear",kde=True)
# Out:
# <Axes: xlabel='TrainingTimesLastYear', ylabel='Count'>

# %%
sns.histplot(data=df, x="YearsAtCompany",kde=True)
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='Count'>

# %%
sns.histplot(data=df, x="YearsInCurrentRole",kde=True)
# Out:
# <Axes: xlabel='YearsInCurrentRole', ylabel='Count'>

# %%
sns.histplot(data=df, x="YearsSinceLastPromotion",kde=True)
# Out:
# <Axes: xlabel='YearsSinceLastPromotion', ylabel='Count'>

# %%
sns.histplot(data=df, x="YearsWithCurrManager",kde=True)
# Out:
# <Axes: xlabel='YearsWithCurrManager', ylabel='Count'>

# %% [markdown]
# ### **Boxplot**

# %%
sns.boxplot(data=df, x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(data=df, x="DailyRate")
# Out:
# <Axes: xlabel='DailyRate'>

# %%
sns.boxplot(data=df, x="DistanceFromHome")
# Out:
# <Axes: xlabel='DistanceFromHome'>

# %%
sns.boxplot(data=df, x="HourlyRate")
# Out:
# <Axes: xlabel='HourlyRate'>

# %%
# ATENÇÃO: Salário Mensal

sns.boxplot(data=df, x="MonthlyIncome")
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
sns.boxplot(data=df, x="MonthlyRate")
# Out:
# <Axes: xlabel='MonthlyRate'>

# %%
sns.boxplot(data=df, x="NumCompaniesWorked")
# Out:
# <Axes: xlabel='NumCompaniesWorked'>

# %%
sns.boxplot(data=df, x="PercentSalaryHike")
# Out:
# <Axes: xlabel='PercentSalaryHike'>

# %%
# ATENÇÃO: Total de Anos Trabalhados

sns.boxplot(data=df, x="TotalWorkingYears")
# Out:
# <Axes: xlabel='TotalWorkingYears'>

# %%
# ATENÇÃO: Horas gastas em treinamento

sns.boxplot(data=df, x="TrainingTimesLastYear")
# Out:
# <Axes: xlabel='TrainingTimesLastYear'>

# %%
# ATENÇÃO: Anos na Empresa

sns.boxplot(data=df, x="YearsAtCompany")
# Out:
# <Axes: xlabel='YearsAtCompany'>

# %%
# ATENÇÃO: Anos na função atual

sns.boxplot(data=df, x="YearsInCurrentRole")
# Out:
# <Axes: xlabel='YearsInCurrentRole'>

# %%
# ATENÇÃO: última promoção

sns.boxplot(data=df, x="YearsSinceLastPromotion")
# Out:
# <Axes: xlabel='YearsSinceLastPromotion'>

# %%
# ATENÇÃO: Anos com o Gerente Atual

sns.boxplot(data=df, x="YearsWithCurrManager")
# Out:
# <Axes: xlabel='YearsWithCurrManager'>

# %% [markdown]
# ### **Removendo OUTILIERS**

# %%
# Cálculo dos quartis
def removendo_outliers_iqr(df,coluna):
  Q1 = df[coluna].quantile(0.25)
  Q3 = df[coluna].quantile(0.75)
  IQR = Q3 - Q1

  # Limites para considerar um valor como outlier
  limite_inferior = Q1 - 1.5 * IQR
  limite_superior = Q3 + 1.5 * IQR

  # Filtrando os dados para remover os outliers
  df_sem_outliers = df[(df[coluna] >= limite_inferior) & (df[coluna] <= limite_superior)]

  print("Antes:", df.shape[0], "linhas")
  print("Depois:", df_sem_outliers.shape[0], "linhas")
  return df_sem_outliers

# %% [markdown]
# * Variável: **MonthlyIncome**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"MonthlyIncome")
# Out:
# Antes: 1470 linhas
# Depois: 1356 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="MonthlyIncome")
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %% [markdown]
# * Variável: **NumCompaniesWorked**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"NumCompaniesWorked")
# Out:
# Antes: 1470 linhas
# Depois: 1418 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="NumCompaniesWorked")
# Out:
# <Axes: xlabel='NumCompaniesWorked'>

# %% [markdown]
# * Variável: **TotalWorkingYears**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"TotalWorkingYears")
# Out:
# Antes: 1470 linhas
# Depois: 1407 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="TotalWorkingYears")
# Out:
# <Axes: xlabel='TotalWorkingYears'>

# %% [markdown]
# * Variável: **TrainingTimesLastYear**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"TrainingTimesLastYear")
# Out:
# Antes: 1470 linhas
# Depois: 1232 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="TrainingTimesLastYear")
# Out:
# <Axes: xlabel='TrainingTimesLastYear'>

# %% [markdown]
# * Variável: **YearsAtCompany**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"YearsAtCompany")
# Out:
# Antes: 1470 linhas
# Depois: 1366 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="YearsAtCompany")
# Out:
# <Axes: xlabel='YearsAtCompany'>

# %% [markdown]
# * Variável: **YearsInCurrentRole**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"YearsInCurrentRole")
# Out:
# Antes: 1470 linhas
# Depois: 1449 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="YearsInCurrentRole")
# Out:
# <Axes: xlabel='YearsInCurrentRole'>

# %% [markdown]
# * Variável: **YearsSinceLastPromotion**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"YearsSinceLastPromotion")
# Out:
# Antes: 1470 linhas
# Depois: 1363 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="YearsSinceLastPromotion")
# Out:
# <Axes: xlabel='YearsSinceLastPromotion'>

# %% [markdown]
# * Variável: **YearsWithCurrManager**

# %%
df_sem_outliers = removendo_outliers_iqr(df,"YearsWithCurrManager")
# Out:
# Antes: 1470 linhas
# Depois: 1456 linhas

# %%
sns.boxplot(data=df_sem_outliers, x="YearsWithCurrManager")
# Out:
# <Axes: xlabel='YearsWithCurrManager'>

# %% [markdown]
# ## **3. Análise Exploratória (EDA)** >>> Será executada no Power BI

# %% [markdown]
# Vou baixar o aquivo tratado sem outliers e importar para o Power BI

# %%
# Salva o DataFrame em um arquivo chamado 'df_sem_outliers.csv'
df_sem_outliers.to_csv('df_sem_outliers.csv', index=False)

# %%
# Baixando o arquivo para computador
from google.colab import files
files.download('df_sem_outliers.csv')
